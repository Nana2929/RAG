# %% [markdown]
# ## Multi-aspect PEPLER (MA-pepler) Result Visualization

# %%
import logging
import os
import random
from pathlib import Path
from pprint import pprint

import torch
from easydict import EasyDict as edict
from torch.utils.data import DataLoader
from transformers import GPT2Tokenizer

from pepler.modeling_pepler import RecReg
from pepler.utils import ReviewHistory, bos, eos, generate, pad, ids2tokens, load_model
from pepler.dataset import (
    AspectDataBatch,
    AspectDataInitializer,
    UserItemDataset,
    FfidfStore,
)

# %%
def parse_args(
    auto_arg_by_dataset: str,
    output_len: int,
    temperature: float,
    device: str,
    model_name: str,
    ffidf_topk: int,
) -> edict:
    args = edict(
        auto_arg_by_dataset=auto_arg_by_dataset,
        output_len=output_len,
        temperature=temperature,
        device=device,
        model_name=model_name,
        ffidf_topk=ffidf_topk,
    )
    assert args.auto_arg_by_dataset in ["yelp23", "gest", "yelp"]

    ROOT = Path(
        "/home/P76114511/projects"
    )  # ROOT = Path(__file__).parent.parent.parent
    CKPT_DIR = Path(
        "/home/P76114511/projects/my_retriever/checkpoints/dset_ver=2_ptr=False_arreg=1.0"
    )
    # ========== Dataset-specific args ==========
    if args.auto_arg_by_dataset == "yelp23":
        dargs = edict(
            data_path=ROOT / "nete_format_data/yelp23/reviews.pickle",
            index_dir=ROOT / "nete_format_data/yelp23/1",
            aspect_path=ROOT / "nete_format_data/yelp23/aspect_category_index.csv",
            checkpoint=CKPT_DIR / "yelp23/run_2/model.pt",
            ffidf_cache_dir=ROOT / "nete_format_data/ffidf_cache/yelp23/1",
            item_meta_path=ROOT
            / "nete_format_data/yelp23/yelp_academic_dataset_business.json",
            user_meta_path=ROOT
            / "nete_format_data/yelp23/yelp_academic_dataset_user.json",
        )
    elif args.auto_arg_by_dataset == "gest":
        dargs = edict(
            data_path=ROOT / "nete_format_data/gest/reviews.pickle",
            index_dir=ROOT / "nete_format_data/gest/1",
            aspect_path=ROOT / "nete_format_data/gest/aspect_category_index.csv",
            checkpoint=CKPT_DIR / "gest/run_3/model.pt",
            ffidf_cache_dir=ROOT / "nete_format_data/ffidf_cache/gest/1",
            item_meta_path=None,
            user_meta_path=None,
        )
    elif args.auto_arg_by_dataset == "yelp":
        dargs = edict(
            data_path=ROOT / "nete_format_data/yelp/reviews.pickle",
            index_dir=ROOT / "nete_format_data/yelp/1",
            aspect_path=ROOT / "nete_format_data/yelp/aspect_category_index.csv",
            checkpoint=CKPT_DIR / "yelp/run_1/model.pt",
            ffidf_cache_dir=ROOT / "nete_format_data/ffidf_cache/yelp/1",
            item_meta_path=ROOT / "nete_format_data/yelp/item.json",
            user_meta_path=ROOT / "nete_format_data/yelp/user.json",
        )
    args = vars(args)
    args.update(dargs)
    args = edict(args)
    return args

# %% [markdown]
# ## Custom Arguments
# - `auto_arg_by_dataset`: the dataset name you want to use; the path arguments are decided based upon this name.
# Currently support `yelp`, `yelp23`, `gest`.
# - `output_len`: the length of the output sequence.
# - `temperature`: the temperature of generated sentence. 0 < temperature <= 1 (the higher the more creative, 0.5 is the best in most cases)
# - `device`: the computational device
# - `model_name`: used to load the tokenizer. Currently only support `gpt2`.
# - `ffidf_topk`: the number of user or item important features to be returned and displayed. The important features are ranked by tfidf (ffidf, first f for `feature`) score.

# %%
args = parse_args(
    auto_arg_by_dataset="yelp23",
    output_len=20,
    temperature=0.5,
    device="cuda",
    model_name="gpt2",
    ffidf_topk=10,
)

# %%
logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s", level=logging.INFO
)
logger = logging.getLogger(__name__)


corpus = AspectDataInitializer(
    data_path=args.data_path,
    index_dir=args.index_dir,
    aspect_path=args.aspect_path,
    tokenizer=None,
)
#  ========== prepare tokenizer and review history ==========
review_history = ReviewHistory(
    corpus.train,
    valid_data=corpus.valid,
    test_data=corpus.test,
    logger=logger,
)
tokenizer = GPT2Tokenizer.from_pretrained(
    args.model_name, bos_token=bos, eos_token=eos, pad_token=pad
)
SPECIAL_TOKEN_IDS = [
    tokenizer.bos_token_id,
    tokenizer.eos_token_id,
    tokenizer.pad_token_id,
]
valid_dataset = UserItemDataset(corpus.valid, tokenizer, bos=bos, eos=eos)
# Out:
# feature set size: 372576
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def inference(
    model: RecReg,
    batch: AspectDataBatch,
    device: str,
    special_token_ids: list[int],
    output_len: int,
    temperature: float,
) -> tuple:
    aspect_rating_predict = []
    idss_predict = []
    with torch.no_grad():
        user = batch.user.to(device)
        item = batch.item.to(device)
        aspect = batch.aspect.to(device)
        aspect_score = batch.aspect_score.to(device)
        text = batch.seq[:, :1].to(device)

        batch_size = user.size(0)
        for idx in range(output_len):
            outputs = model(
                user, item, aspect, text, mask=None, aspect_score=aspect_score
            )
            if idx == 0:
                # add a batch dimension if batch_size == 1
                aspect_rating = (
                    outputs.aspect_rating.unsqueeze(0)
                    if batch_size == 1
                    else outputs.aspect_rating
                )
                aspect_rating_predict.extend(aspect_rating.tolist())

            last_token = outputs.logits[:, -1, :] / (temperature + 1e-10)
            word_prob = torch.softmax(last_token, dim=-1)
            token = torch.multinomial(word_prob, num_samples=1)
            text = torch.cat([text, token], dim=-1)
        ids = text[:, 1:].tolist()  # remove <bos>
        # remove <bos>, <eos>, <pad> in the middle
        # ids = [[x for x in y if x not in special_token_ids] for y in ids]
        idss_predict.extend(ids)
    return aspect_rating_predict, idss_predict

# %% [markdown]
# ## Retrieval Results
# - For every user-item pair, we create a batch.
# - Every user-item pair in raw data is a review. For training purpose, we segment the review into multiple segments
# based on the aspect category (`category`). Hence a batch contains a dynamic number of segments ($1 <= number\_of\_segments <= 28$).
# - Each display is to display the user, the item, and the gold segments, along with the generated texts based on `user, item, category` prompt tokens.

# %%
ffidf_store = FfidfStore(args.ffidf_cache_dir)
# Out:
# Loading precomputed ffidf values from /home/P76114511/projects/nete_format_data/ffidf_cache/yelp23/1
# Loaded 35152 users and 24199 items.
# Loading completed.

# %% [markdown]
# #### Coloring Scheme

# %%
# !! `retrieve.py` has not fixed the batch size= 1 issue
# !! load item name if available


from termcolor import colored

ID_COLOR = "on_green"
ID_COLOR2 = "on_cyan"
GOLD_COLOR = "light_yellow"
PRED_COLOR = "light_blue"


print_gold = lambda x: print(colored(x, GOLD_COLOR))
print_predict = lambda x: print(colored(x, PRED_COLOR))
print_user_id = lambda x: print(colored(x, "black", ID_COLOR))
print_user_info = lambda x: print(colored(x, ID_COLOR.lstrip("on_")))

print_item_id = lambda x: print(colored(x, "black", ID_COLOR2))
print_item_info = lambda x: print(colored(x, ID_COLOR2.lstrip("on_")))

# %% [markdown]
# ## Display
# - `RAND_INDEX` selects a random user-item pair from the validation dataset.
# - We first load the fine-tuned Multi-aspect PEPLER model to predict `user-item-aspect` rating and generate texts.
# - `user_id`: user's id string in raw data
# - `item_id`: item's id string in raw data; ONLY SOME raw data provides the item's name and if so, we also display the item's name.
# - `user(item)_ffidf_features` are pre-computed ffidf-score-ranked features (features are extracted using sentiment UIE model).
#    These features may help identified the user's preferences and the item(restaurants)'s characteristics.
# - `user(item)_review_history` are user or item's reviews in the train set.

# %%
import json


def load_jsonl(path: os.PathLike):
    with open(path, "r") as f:
        return [json.loads(line) for line in f]

# %%
if args.user_meta_path is not None and args.item_meta_path is not None:
    user_meta = load_jsonl(args.user_meta_path)
    item_meta = load_jsonl(args.item_meta_path)

# %%
user_id2meta = {x["user_id"]: x for x in user_meta}
item_id2meta = {x["business_id"]: x for x in item_meta}

# %%
# ========== randomly select a user-item pair for results visualization ==========
RAND_INDEX = random.randint(0, len(valid_dataset) - 1)

# %%
print(f"random index: {RAND_INDEX}/{len(valid_dataset)}")
data = valid_dataset[RAND_INDEX]
user, item = data.user, data.item
user_id, item_id = corpus.user_dict.get_entity(user), corpus.item_dict.get_entity(item)
batch = valid_dataset.collate_fn(data)
model = load_model(args.checkpoint)
aspect_rating_predict, idss_predict = inference(
    model,
    batch,
    args.device,
    SPECIAL_TOKEN_IDS,
    args.output_len,
    args.temperature,
)
# ========== ffidf features ==========
user_ffidf_features = ffidf_store.get_user_ffidf(
    user_id, topk=args.ffidf_topk, return_score=True
)
item_ffidf_features = ffidf_store.get_item_ffidf(
    item_id, topk=args.ffidf_topk, return_score=True
)

# ========== review history ==========
user_review_history_idx = review_history.get_user_history(
    user, hide_item=item, return_embedding=False
)
item_review_history_idx = review_history.get_item_history(
    item, hide_user=user, return_embedding=False
)

# BELOW demonstrates how to get review content
user_review_history = [corpus.train[i] for i in user_review_history_idx]
item_review_history = [corpus.train[i] for i in item_review_history_idx]

user_review_history_text = [d["text"] for d in user_review_history]
item_review_history_text = [d["text"] for d in item_review_history]

batch_size = len(batch)

print_user_id(f"user_id: {user_id}")
if args.user_meta_path is not None:
    print_user_id(f"user name: {user_id2meta[user_id]['name']}")

for tuple in user_ffidf_features:
    print_user_info(f"{tuple}")


print_item_id(f"item_id: {item_id}")
if args.item_meta_path is not None:
    print_item_id(f"item name: {item_id2meta[item_id]['name']}")
# id name
for tuple in item_ffidf_features:
    print_item_info(f"{tuple}")


print(f"# aspect categories mentioned in gold review: {batch_size}")

print_gold(f"gold overall rating: {data.rating}")
for i in range(batch_size):
    d = data[i]
    predict_text_ids = idss_predict[i]
    predict_aspect_rating = aspect_rating_predict[i]
    predict_text = ids2tokens(predict_text_ids, tokenizer, eos)

    print_gold(f"\tcategory: {d['category_name']}")
    print_gold(f"\tgold text: {d['text']}")
    print_gold(f"\tgold feature(s): {d['feature']}")
    print_predict(f"\tpredict text: {' '.join(predict_text)}")
    print_gold(f"\tgold aspect-rating: {d['rating']}")
    print_predict(f"\tpredict aspect-rating: {predict_aspect_rating}")
    if i < batch_size - 1:
        print("\t=========== ")

pprint(f"user's review history: {user_review_history_text}")
pprint(f"items's review history: {item_review_history_text}")
# Out:
# random index: 94449/170879
# user_id: 8a00hdf5M5cr8D1aNi5hUA
# user name: Karl
# ('individual salsa bowls', 0.35888773927808937)
# ('pad kee mow beef', 0.35888773927808937)
# ('pad kee mow', 0.29653884185304)
# ('peach butter', 0.2838982114544177)
# ('pad see ewe', 0.27901491497825076)
# ('vegetable', 0.24918017038108284)
# ('pork taco', 0.2309972915799755)
# ('country fried steak', 0.22450897915051574)
# ('queso dip', 0.2105154133470587)
# ('beef pho', 0.19524939152146756)
# item_id: vgaDkuxjt8-w-0PtE8tTCA
# item name: Yolk - City Way
# ('food', 0.3024494100962948)
# ('breakfast', 0.28144553613252876)
# ('cinnamon roll french toast', 0.26492258461430296)
# ('coffee', 0.2533889246050116)
# ('pancake', 0.23425780275669422)
# ('service', 0.23262131228525731)
# ('brunch', 0.2120751972504243)
# ('strawberry orange juice', 0.18032767977914366)
# ('french toast', 0.17038124009699696)
# ('egg', 0.15775197671253036)
# # aspect categories mentioned in gold review: 2
# gold overall rating: 2.0
# 	category: American Cuisine
# 	gold text: food was average
# 	gold feature(s): ['food']
# 	predict text: food was good
# 	gold aspect-rating: 0.0
# 	predict aspect-rating: 1.0227084159851074
# 	===========
# 	category: Tapas Bars
# 	gold text: Service was decent
# 	gold feature(s): ['service']
# 	predict text: great service
# 	gold aspect-rating: -1.0
# 	predict aspect-rating: 0.8722192645072937
# ("user's review history: ['love improv. Matt did a great', 'high standards "
#  "with Thai food', 'decent array of stores', 'traditional style tacos and "
#  "cuisine', 'Price was more than reasonable. fresh the meat', 'fresh the meat "
#  "and vegetables', 'friendly service', 'eclectic feel to it , all the way from "
#  "the wine fridge to the wine bottle lamp. great place. cool decor', 'menu , "
#  'which is pretty freaking awesome\', "fish tacos , as they use Cat fish , so '
#  'it \'s a nice", \'individual salsa bowls is nice\', \'Food was just ok\', '
#  "'decent food', 'rooftop is such a great', 'noodles and beef were very dry', "
#  "'beef were very dry', 'nice selection. theatre is clean', 'salsa and chips "
#  "is never a bad', 'salsa and chips is never a bad', 'timely service', "
#  "'burgers on the menu all sound amazing and creative', 'country fried steak "
#  "and eggs and have never been disappointed . Its worth', 'meat was delicious. "
#  "enjoyed the food']")
# ('items\'s review history: [\'drinks are made right they are great\', "GF '
#  'toast , it \'s delicious", \'delicious as is the jam\', \'wings extra sauce '
#  '. SO GOOOOOD ! Thanks for the extra sauce . The blue cheese has great flavor '
#  'for dipping . \\n - Italian sub . I would have preferred this hot vs served '
#  'cold . My fiancé loved as is . I doctored mine up by toasting bread and '
#  "warming up in the inside . Still delicious', 'large menu', 'good options . "
#  "My husband has been loving the chicken and waffles covered in gravy', 'good "
#  'options . My husband has been loving the chicken and waffles covered in '
#  "gravy', 'legs had so much water in them . The flavor was well seasoned', "
#  "'service and food are great', 'fresh juices they have are indeed fresh and "
#  "delicious', 'food did finally arrive it was very good', 'good experience "
#  "today . Had a glazed round donut', 'fantastic lamb Gyro', 'shrimp po boy . "
#  "He has heard it was good', 'fresh ingredients', 'excellent , it   beated   "
#  'any famous bakery or   Ybor City restaurant   in the category of Cuban '
#  'sandwich\', "gluten free crust even more than their standard crust . We had '
#  "it with their potato skins which we also enjoyed . \\n\\n So , we 're happy "
#  "to keep coming to Ricks . We 're definitely going to be taking advantage of "
#  'that delicious", \'red velvet French toast , French toast trip , bagel '
#  "sandwich and eggs and sausage for the family . Everything was delicious', "
#  '\'coffee was so good\', \'service was exceptional\', "great Tuesday Tomahawk '
#  "special. great then , and it certainly did n't disappoint now . \\n\\n Some "
#  'negative things that had changed ... our wines", \'Coffee as good\', \'Fruit '
#  "was super fresh and seasonal', 'pretzels are so soft , fresh', 'portions are "
#  "small. prices are high', 'nice portion sizes', 'perfect brunch', 'crust was "
#  "acceptably crispy', 'not great service', 'comparable to some grocery ice "
#  "cream , lacked some flavor. Disappointing gelato', 'service and food to be "
#  "consistently very good', 'cute young girl. great prices. enjoyed their house "
#  "red and white wines', 'best pizza', 'pancakes were so soft and fluffy. "
#  "chicken and waffles which were amazing', 'chicken and waffles which were "
#  "amazing', 'good kitchen. ribeye medium rare and it came out steaming', "
#  "'service was really good', 'chicken and waffles were really tasty', 'chicken "
#  "and waffles were really tasty', 'bacon was crispy', 'service stunk', 'brunch "
#  "location make it a fun and cheerful', 'good food', 'syrup was not fresh', "
#  "'not fresh ( standard bottle syrup ) .   The gravy', 'cool place. food was "
#  "great', 'Huge sandwiches', 'shredded chicken Jalisco burrito no lettuce and "
#  "it was one of the best', 'chorizo on really anything is wonderful', "
#  "'strawberry orange juice is worth', 'enjoyed dinner', 'Lobster Ravioli was "
#  "incredible', 'breakfast was compliant ( and awesome', 'unusual and filling "
#  "appetizers', 'fun and great tasting ! The coffee', 'kids menu was fun', 'fun "
#  "hip youngsters !  \\n The kids loved their smores pancakes', 'big with lots "
#  "of choices . From yogurt to crepes ,   to pancakes , espresso', 'soup I "
#  "tasted a sample of ( mushroom ) was to die for - excellent', 'soup was hot. "
#  "California Omelette and the flavor was pretty good. toast was thick', "
#  "'familiar staples but I love their twist on French fries and pork "
#  'tenderloin. drink selection is great. great . \\n\\n The menu. nice '
#  "restaurant. price is reasonable', 'Love this place . Any beer', 'bright , "
#  "friendly decor. free wifi', 'friendly decor and service', 'kale scramble "
#  'came with a choice of potatoes or fruit AND pancakes ! Everything was '
#  'delicious\', \'food is good , not always the best\', "friendly hostess and '
#  'seated at the counter and promptly seabed coffee . The menu was brought '
#  'swiftly and witching 5 seconds ( given that I am none of these things ) '
#  'ordered the big , fat , Greek omelette with a fruit side and pancakes of '
#  'course . As I waited I glanced around and saw a mixed bag of 20 - 30 '
#  "somethings peppered with some older people . I did n't have much time to "
#  'look around as my food was out in around 5 minutes . Here we go : \\n\\n '
#  'Omelette :   5 eggs , feta , tomato , onion", "friendly hostess and seated '
#  'at the counter and promptly seabed coffee . The menu was brought swiftly and '
#  'witching 5 seconds ( given that I am none of these things ) ordered the big '
#  ', fat , Greek omelette with a fruit side and pancakes of course . As I '
#  'waited I glanced around and saw a mixed bag of 20 - 30 somethings peppered '
#  "with some older people . I did n't have much time to look around as my food "
#  'was out in around 5 minutes . Here we go : \\n\\n Omelette :   5 eggs , feta '
#  ', tomato", \'great - fluffy yet all the fillings\', \'cost of $ 30 is '
#  "extremely cheap', 'enjoyed this take out', 'good coffee', 'raw pepper pieces "
#  ". They were crunchy and really overpowered', 'tortillas were not crispy . "
#  "They were soggy and slimy', 'pancakes but they were fluffy with a subtle "
#  "vanilla taste that was delectable', 'food is good. place is always packed. "
#  "tables are so close', 'tasty cheap street meats', 'awesome , in one word ! "
#  "\\n\\n The bar. satisfied with their meals , the atmosphere', 'chicken and "
#  "waffles . They were very good', 'recommend adding an egg', 'croque Madame "
#  'she liked\', \'favorite microbreweries\', "good and I knew from last time to '
#  'add avocado . I \'m not a fan of their home fries", \'Food is always '
#  'consistently good. staff is friendly. menu offers many. decor is very clean '
#  "and welcoming', 'menu well . When I go back , I will definitely ask for his "
#  "table .   The food came out pretty quickly', 'kung pao soy chicken is really "
#  "good , very flavorful and delicious', 'tons of wait staff', 'menu changed', "
#  "'healthy fats', 'catfish is great', 'disappointed at the lack of any gluten "
#  "free options', 'disappointed at the lack of any gluten free options for "
#  "toast or English muffin', 'Food is amazing', 'great drinks', 'service was "
#  "good', 'décor cool', 'slow service. portion size was huge and tasty', "
#  "'ingredients are fresh', 'lady that I had was attentive', 'positive was "
#  "portions. under cooked as was the egg', 'Croque Madame was missing cheese. "
#  'missing cheese and the omelette\', \'love their outdoor patio\', "good store '
#  'for most your athletic needs . \\n\\n I usually go here for my running and '
#  "cross training shoe wear . They usually have better sale deals that it 's "
#  'big store counter parts . Also I looked for a pair of shoes online and found '
#  'them with a discount but with shipping and the waiting time for the shipping '
#  '. Your better off buying here . Not to mention they could ship off the wrong '
#  'pair of shoes . Which could be a pain in the butt . That is why I prefer to '
#  'buy my shoes local and at the stores . I have had the wrong pair sent to me '
#  'too many times . I am the type to really use the crap out of my shoes and if '
#  "I get the shoe late how am I suppose to workout . I know I 'm rambling now "
#  "but online purchases pisses me off sometimes haha . It 's not all bad "
#  'experiences . But as I said I prefer getting my workout shoes at the store '
#  'location . \\n\\n Parking", \'meal was middle of the road food\', \'cows '
#  "must have been happy and stress free', 'Unlimited toppings. toppings are "
#  "amazing and overwhelmingly wonderful', 'best fries', 'liked the orange "
#  "juice', 'love French toast', 'quality and styles are great', 'server seemed "
#  'rushed. great variety of creative and traditional breakfast and brunch '
#  "offerings. not so great . Our server', 'gal that was reading and running the "
#  'event was wonderful\', "marinated beef dishes are not of Korean origin , '
#  'though I \'m not sure it was intended to be , it was a little misleading", '
#  '\'Great service\', \'reasonable prices\', "fun ! \\n\\n I do n\'t know if it '
#  "'s really worth what you spend , although I do n't regret going . We really "
#  'enjoyed it . \\n\\n I gave them 4 stars instead of 5 because they were a '
#  'little too obnoxious with the upsells . We bought the family package and '
#  'after checking in they are selling you a high flyer add on and then a '
#  "virtual reality add on . And because it 's your first time you have no idea "
#  "what you 're signing up for but you just start OK - ing everything . \\n\\n "
#  'While you \'re in the wind tunnel", \'overpriced $ 18 for a turkey burger '
#  "and handful of fries', 'disappointing .   The beans', 'wait staff were all "
#  "pleasant and attentive', 'menu selection may seem overwhelming', 'atmosphere "
#  "was very open and social', 'wait for 2 was less than 15 minutes', 'service "
#  "was lackluster', 'hostess to the servers , everything is usually great', "
#  "'great food', 'cool arrangement but the parking. starter looked like a pizza "
#  "pie but had onions and something else on it almost a sweet. beautiful area', "
#  "'colorful and contemporary vintage fashion', 'Nutella crepes were amazing', "
#  '\'service was great\', \'dishes are full of complexity and flavor\', "french '
#  'toast , they have about five other varieties .   Same goes for their eggs '
#  "benedict .   The portions are generous and it 's not uncommon to leave with "
#  "a to - go box . \\n My first visit was Yolk 's first weekend open .   As "
#  'expected , service was a bit slow and they were obviously still working out '
#  'some kinks .   I returned today ( because of the menu and tasty", \'great '
#  "service', 'Nissan Titan cash & Shannon made my purchase probably the best & "
#  "fastest', 'love this place ! During our visit this weekend , we got the "
#  "infamous strawberry orange juice', 'love this place ! During our visit this "
#  'weekend , we got the infamous strawberry orange juice , veg skillet with '
#  "eggs', 'love this place ! During our visit this weekend , we got the "
#  'infamous strawberry orange juice , veg skillet with eggs and the nutella '
#  'crepes\', \'okay sushi\', "breakfast in an extremely timely manner , and boy '
#  'did it not disappoint ! I had the kale scrambler and got a little crazy by '
#  'subbing my toast for a slice of red velvet french toast . My brunch life '
#  "will be forever changed . I 'm not one for sweet breakfasts , but this "
#  'addition was perfect", \'fresh strawberries\', \'Delicious food\', \'West '
#  "Coast crepes and it was great. adore the red velvet French toast', 'food and "
#  'service were fantastic\', \'service were both good\', "underwhelming '
#  "breakfast joint . \\n\\n This is one of the first places that I 've been to "
#  'that had decent , not watered - down coffee", \'half rack of ribs ( which he '
#  "claims were delicious', 'unpretentious and bro - free bar', 'French toast "
#  "was awesome', 'tables were sticky. food was OK', 'yummy seasonal flavors', "
#  "'good variety of food', 'fruit was very fresh', 'large helping too . Our "
#  'waitress was friendly and made conversation , and kept our coffee. potatoes '
#  ". The fruit was very fresh', 'Menu is very clean and clear', 'friendly and "
#  "welcoming staff', 'pancakes were tasty', 'Decent hotel', 'staff are sooo "
#  "incredibly friendly', 'good : they have espresso drinks', 'South of the "
#  "border ... yum', 'bread and meats for dipping are great. selection of cheese "
#  'is delicious\', "amazing every time I \'ve been there so far . I love the '
#  'fact that they have options for hot sauce", "amazing every time I \'ve been '
#  'there so far . I love the fact that they have options for hot sauce .   It '
#  '\'s brunch", \'strong Chinese tea\', \'California omelette and the cinnamon '
#  "roll French toast . Both were so flavorful and delicious', 'cinnamon roll "
#  "French toast . Both were so flavorful and delicious', 'decor is sunshine "
#  "cute', 'easy bar', 'pancakes / omelette are all available . Some "
#  "traditional', 'Great wait staff', 'Excellent food', 'atmosphere is great', "
#  "'food is always good', 'waiters/ waitresses are great', 'spicy mint chutney. "
#  "complimentary papadum with sweet tamarind sauce', 'food was overpriced', "
#  "'excellent food. enjoy Cajun food', 'cream cheese as well , it all tasted "
#  'extra yummy with some Cholula ! I got the diced red potatoes which were not '
#  'super impressive , not really seasoned at all . It comes with an extra carb '
#  'side which I always enjoy so I picked the pancakes which were also '
#  "delicious', 'good the bread. dark , caramelized crust', 'Great place', 'food "
#  'goes , it was pretty mediocre\', \'awesome food\', "pancakes and waffles , '
#  "you really ca n't go wrong here ! Last time I went I ordered the classic "
#  'Belgian waffle topped with powdered sugar and melted chocolate chips with a '
#  'drizzle of warm maple syrup . Is your mouth watering", "omelettes because I '
#  'heard they \'re incredible", \'generous portion of St Louis Style Spare '
#  "ribs', 'amazing oak milk latte. portions are HUGE', 'Disappointed in the "
#  'food\', "brunch . I asked regarding alcohol and was informed it was bring '
#  "your own , but have to purchase their juice . No brainer - that 's awesome ! "
#  "! ! ! ! ! ! They do n't have the glasses really for the speciality drinks / "
#  'mimosas but oh well . Most reasonable", "waitress said she could only do '
#  "parties of 4 . So we said we 'd do 2 parties of 4 . She said they would n't "
#  'allow it . And if we left and came back to try to get 2 tables , she would '
#  "refuse to let us in . I 've never had an experience like this ! She was so "
#  'rude", \'great and the coffee\', \'food is just ok\', \'lackluster whole '
#  "wheat pancake', 'bean and veggie burritos from here and they made them "
#  "pretty quick and they were so good sized and very flavorful', 'habanero "
#  "sauce here . My food was excellent', 'pancakes were perfectly cooked', 'chai "
#  "tea was extremely hot', 'disappointed in the steamed dumplings', 'bacon "
#  'waffle turned out to be mini waffles and were too much crunch. sourdough '
#  'toast was also decent. smokey bacon .   If you end up going to any Yolk '
#  "location , the one thing I would definitely recommend', 'Service at the bar "
#  "was friendly and efficient', 'food is pretty good not spectacular but pretty "
#  "good and decent. Stephanie was extremely attentive', 'mimosas were great', "
#  "'fried potatoes were hard', 'steak was mediocre', 'server seemed rushed', "
#  "'great service', 'OK and service', 'Starbucks has been terribly designed', "
#  "'service is great', 'pesto was fine', 'mediocre food', 'servers were "
#  "attentive', 'fine dining', 'potatoes were a little bland and kind of cold', "
#  "'Solid 4 star breakfast', 'location was prime. food was out of this world . "
#  "I had the chicken n waffles and it was amazing', 'kind and attentive "
#  "waitress', 'Excellent service', 'pleasantly surprised by\\u200b this place', "
#  "'solid breakfast and brunch', 'great veggie tacos', 'space is really tight', "
#  '"sacred about a book. awful music. friendly but more importantly , he '
#  'understands the importance of the written word . Almost of the their books '
#  'are used , some are first editions and even print printings going back to '
#  "the ' 40s and earlier . But each book is loved and cared for as though it "
#  'were a pet or an infant , but with pages and a cover and things . \\n\\n '
#  'Prices are reasonable but can get pretty hefty once you peruse the more rare '
#  'texts . \\n\\n If I have one complaint , it \'s that the staff", \'chicken '
#  'and waffles and they did a. Number on that cause " man , that was good. '
#  "California omelet which sounded great', 'chicken and waffles and they did a. "
#  'Number on that cause " man , that was good\', \'Environment : great\', '
#  "'syrup was good. French toast with strawberries and strawberry orange juice "
#  '- a regular item I order ! My eggs were delicious overall but were a little '
#  "too soft / gooey in some parts . The French toast was really good', 'French "
#  'toast with strawberries and strawberry orange juice - a regular item I order '
#  '! My eggs were delicious overall but were a little too soft / gooey in some '
#  "parts . The French toast was really good', 'waitress greeted us apologizing "
#  'for the wait . She noticed her co - worker was overwhelmed and came over to '
#  'help out which I thought was a great showing of teamwork . \\n\\n We both '
#  'got a skillet as our main . I got Parma while my boyfriend got the farmhouse '
#  '. Our skillets were piping hot , the hash had a char but was still tender , '
#  'and our eggs were still runny . The toast is multigrain and are pretty thick '
#  ', kind of like Texas toast . The strawberry jam was super delicious and '
#  'fresh . We also got a Belgian waffle to share and the berry compote was the '
#  'best. impressed with the brunch here . I signed up for the waitlist before '
#  'my boyfriend and I left the house since it was Saturday at noon . It was '
#  'about a 20 minute drive and when we arrived we only had to wait 5 minutes '
#  "for our table . Our server', 'food . So sweet and genuine. presentation was "
#  "beautiful', 'delicious ! The fritatta', 'Love the concept', 'steep \\n\\n "
#  'Been wanting to go to Yolk for some time . It is a lovely place and the '
#  'staff were very kind and attentive . \\n\\n But between the food and the '
#  "price', 'great location. Best hoagie rolls', 'recommend ordering the coffee "
#  "and the   chilaquiles verdes', 'drunken noodles were tasty', 'love the "
#  "biscuits and gravy', 'love the biscuits and gravy ( Farmhouse', 'coffee is "
#  "great', 'service is always pleasant and fast', 'Clean establishment', 'Good "
#  'coffee\', \'Beautiful views\', "nutty monkey cakes to the red velvet French '
#  'toast , they \'re all rich , decadent and delicious", \'regular brewed '
#  'coffee is not great\', "bar where we like interacting with the staff . Even '
#  "when the place is very busy , they 're always friendly. omelets can be made "
#  "with egg whites . And there 's a great variety of veggies to add in to their "
#  'dishes . \\n\\n Again , they have lots of delicious", \'food is great and '
#  "always fresh and hot', 'love their smoked salmon scramble . I order it with "
#  "fruit', 'love their smoked salmon scramble . I order it with fruit instead "
#  "of potatoes', 'staff here is very friendly and efficient', 'atmosphere was "
#  "different', 'fried potatoes were crispy. scrambled eggs , extra fluffy', "
#  "'mushroom was juicy and full', 'good service', 'food was delicious', 'Great "
#  "service', 'Service was alright', 'house special noodle soup which was "
#  "perfect', 'savory dishes , and everything was good', 'Service was good', "
#  "'fun staff. great food', 'Cinnamon Roll French toast is amazing', 'Employees "
#  "were friendly and nice', 'grilled salmon and eggs . The salmon was cooked to "
#  'perfection\', "Protein and Eggs plate and it \'s delicious simplicity. '
#  'lacked seasoning", \'Cheesy Bread " ( homemade bread sticks with creamy '
#  'garlic sauce , topped with cheese and Italian herbs - $ 9 ) . This was a '
#  "great', 'eggs but they looked pretty delicious. berries were amazing , they "
#  "were sweet and delicious', 'cool dive bar', 'atmosphere is great and very "
#  "welcoming', 'citrus blast salad . It was a good size', 'bread is to die for. "
#  "burgers are amazing', 'waitress was very nice', 'service was kind of "
#  "strange', 'bacon was unevenly cooked. eggs tasted kind of strange. Prices "
#  "are reasonable', 'French toast was fine', 'Great food', 'food is even "
#  "better', 'Small dive bar', 'food is actually pretty good. restaurant itself "
#  "that is a downer', 'good service', 'beautiful Japanese house', 'cinnamon "
#  "roll French toast and red velvet French toast are extremely rich', 'ice "
#  "cream was so smooth and rich. Ice Cream there and it was so good', 'good "
#  "especially the service', 'Cava Cocktail with guava ( very good', 'fries were "
#  "crisp. crisp bacon', 'no chicken', 'atmosphere ! ! Its a great', 'portions "
#  "were large', 'love the fajita burrito and the chimichanga manzana', 'waiter "
#  "was very pleasant. wonderful tenor', 'nice wait staff', 'Tonewood beer is "
#  "perfect , and unique', 'beer garden with picnic tables set up throughout . "
#  "Very inviting. tiny bar', 'food how ever , was just good. menu was "
#  'extensive\', "love Old Nelson \'s - I am a regular here , and I \'ve even '
#  'added their phone number to my contacts because I work across the street and '
#  'want to check the daily soup(s ) before leaving my building . \\n\\n Every '
#  'sandwich here is made - to - order and you can make substitutions and/or '
#  'additions ( though some come at an additional cost ) . I personally like to '
#  'substitute spinach", \'delicious .   I ordered chicken and waffles with '
#  'sausage gravy. chicken and waffles with sausage gravy .   It was delicious '
#  "and so filling', 'delicious .   I ordered chicken and waffles with sausage "
#  'gravy. chicken and waffles with sausage gravy .   It was delicious and so '
#  "filling', 'atmosphere was great', 'Shrimp tempura mango coconut roll is "
#  'awesome\', \'modern décor\', "modern décor to fit the urban chic going on in '
#  "that part of Indianapolis . Having said that , Yolk 's menu in the five "
#  'plates we experienced lacked in creativity , taste , and appearance despite '
#  'the high prices for selections for breakfast", \'Panera Bakery bought five '
#  'Paradise Bakery and Cafes in the area .   Apparently , under the rules and '
#  'guidelines , it will never be called Panera .   The manager sat down with my '
#  'fiance for about 15 minutes explaining the business side of the merger .  '
#  '\\n\\n They mostly adhere to Paneras menu ... the you pick two , sandwiches '
#  ', salads , baked goods , breads , soups , bagels , beverages .... but they '
#  'added hot breakfasts like scrambled eggs , but took away the drool worthy '
#  'souffles ( insert a wimper / pouty face ) !   They kept the Paradise Cookies '
#  ', that they were known for .   They bring the food out to your table , '
#  'unlike Panera ... and they had two naturally flavored unsweetened teas ( '
#  'green and black ) as well as iced coffee as your standard beverages options '
#  "in the self serve area .   I thought that was nice', 'excellent , food. "
#  'amazing here . They have tacos , tortas , quesadillas , and salads available '
#  "to try , plus specials on drinks', 'Cooking could be better. music and "
#  'ambiance are great\', "favorite bit , being a tea drinker , is rather than '
#  'those dinky little nyquil cups with a handle that pass for a \' tea pot", '
#  "'sushi here is good', 'great vibe', 'fouls smell', 'coffee was lukewarm', "
#  "'restrooms were clean. decor is bright. bright and the large windows', 'bar "
#  "was still crazy', 'confit chicken wings and all three sauce options stole "
#  'the show ( the downside , needing to decide to between eating the wings as '
#  "they were , or indulging in the sauces , it was too delicious', 'server was "
#  "friendly and attentive', 'fruit , which was perfectly ripe', 'appetizers , "
#  'fried zucchini which were pretty good\', \'long wait time\', "hip decor. '
#  "bathrooms is n't 5 - stars so do not stay here if you looking for that . "
#  'Also , it seems that rooms to the left side of the motel are quieter than '
#  'the right side but that all depends on your neighbors too . My first PCI '
#  'visit was somewhat quiet", \'coffee is good\', "chilaquiles .   They \'ve '
#  'upgraded ( in my humble Mexican opinion ) the salsa verde .   They used to '
#  "just I 've you red tomato salsa to put over stuff , no more my friends !   "
#  'Salsa verde is pretty tasty", \'Chai Latte made with soy .   It was super '
#  "tasty', 'lovely space', 'Delicious hot pot', 'prices went up', 'awesome "
#  "shops', 'portion sizes would be massive. service was great', 'pizza slices . "
#  "so i stopped in and tried them . very cute. whole pies that are unique', "
#  "'food is amazing. waiter is upbeat and great', 'Great little dive bar']")
